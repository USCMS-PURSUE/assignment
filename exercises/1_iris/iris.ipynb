# %% [markdown]
# # Iris Dataset Analysis

# %% [markdown]
# ## Prepare the dataset

# %% [markdown]
# Use `numpy` or to load `data/iris.data`. Remember to look at the file contents to understand the data format.

# %%
import numpy as np

X = np.loadtxt('iris.data', delimiter=',', usecols=(0,1,2,3), dtype=float)
y = np.loadtxt('iris.data', delimiter=',', usecols=4, dtype=str)

print('X shape:', X.shape)
print('y shape:', y.shape)
# Out:
# X shape: (150, 4)
# y shape: (150,)
# C:\Users\pursue\AppData\Local\Temp\ipykernel_33908\2369243698.py:4: UserWarning: Input line 151 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   y = np.loadtxt('iris.data', delimiter=',', usecols=4, dtype=str)

# %% [markdown]
# Create a map that returns the attribute name given the attribute index.
#
# - 0 -> sepal length
# - 1 -> sepal width
# - 2 -> petal length
# - 3 -> petal width

# %%
attribute = {
    0: 'sepal length',
    1: 'sepal width',
    2: 'petal length',
    3: 'petal width'
}

# %% [markdown]
# ## Data analysis

# %% [markdown]
# Write a function that prints the mean and another that prints the standard deviation of each attribute.

# %%
def findmean(data):
    mean = sum(data)/len(data)
    print(f"Mean is {mean}")

def findstd(data):
    std = np.std(data)
    print(f"STD is {std}")

for i in range(0,4):
    data = X[:, i]
    findmean(data)
    findstd(data)
# Out:
# Mean is 5.843333333333335
# STD is 0.8253012917851409
# Mean is 3.0540000000000007
# STD is 0.4321465800705435
# Mean is 3.7586666666666693
# STD is 1.7585291834055212
# Mean is 1.1986666666666672
# STD is 0.7606126185881716

# %% [markdown]
# Use the functions you defined above to print the mean of the attributes for each class.

# %%
classes = np.unique(y)
for cls in classes:
    print(f"Means for class {cls}:")
    for i in range(4):
        data = X[y == cls, i]
        print(f"{attribute[i]}:", end="")
        findmean(data)
    print()
# Out:
# Means for class Iris-setosa:
# sepal length:Mean is 5.005999999999999
# sepal width:Mean is 3.4180000000000006
# petal length:Mean is 1.464
# petal width:Mean is 0.2439999999999999
#
# Means for class Iris-versicolor:
# sepal length:Mean is 5.936
# sepal width:Mean is 2.7700000000000005
# petal length:Mean is 4.26
# petal width:Mean is 1.3259999999999998
#
# Means for class Iris-virginica:
# sepal length:Mean is 6.587999999999998
# sepal width:Mean is 2.9739999999999998
# petal length:Mean is 5.552
# petal width:Mean is 2.026

# %% [markdown]
# Now, let's plot this data. Use `matplotlib` to create scatter plots for petal and sepal. Use different colors for each class.

# %%
import matplotlib.pyplot as plt

colors = {
    'Iris-setosa':      'r',
    'Iris-versicolor':  'g',
    'Iris-virginica':   'b'
}

for species in np.unique(y):
    mask = (y == species)
    plt.scatter(X[mask, 0], X[mask, 1], c=colors[species], label=species)

plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.title('Sepal dimensions by class')
plt.legend()
plt.show()

for species in np.unique(y):
    mask = (y == species)
    plt.scatter(X[mask, 2], X[mask, 3], c=colors[species], label=species)

plt.xlabel('Petal length')
plt.ylabel('Petal width')
plt.title('Petal dimensions by class')
plt.legend()
plt.show()
